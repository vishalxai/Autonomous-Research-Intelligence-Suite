# %%
import os
from dotenv import load_dotenv
from autogen_agentchat.agents import AssistantAgent
from autogen_ext.models.openai import OpenAIChatCompletionClient
from autogen_agentchat.teams import RoundRobinGroupChat
from autogen_agentchat.ui import Console

load_dotenv()
or_key = os.getenv("OPENROUTER_API_KEY")

# %%
# 1. The Cloud Brain (Auto-Routing Load Balancer)
# Since this is a text task, the router will dynamically bypass all 429 traffic jams!
cloud_client = OpenAIChatCompletionClient(
    model="meta-llama/llama-3.3-70b-instruct",
    api_key=or_key,
    base_url="https://openrouter.ai/api/v1",
    model_info={"vision": False, "function_calling": True, "json_output": False, "family": "unknown"}
)
# Out:
# /Users/vishalsingh/Documents/GIT/Autonomous-Research-Intelligence-Suite/venv/lib/python3.13/site-packages/autogen_ext/models/openai/_openai_client.py:466: UserWarning: Missing required field 'structured_output' in ModelInfo. This field will be required in a future version of AutoGen.
#   validate_model_info(self._model_info)

# %%
# 2. The Local Brain (Fast Processing/Formatting)
local_client = OpenAIChatCompletionClient(
    model="llama3.2",
    api_key="placeholder",
    base_url="http://localhost:11434/v1",
    model_info={"vision": False, "function_calling": True, "json_output": False, "family": "llama3"}
)

print("✅ Block 1 & 2: Cloud Brain swapped to the OpenRouter Free Load-Balancer!")
# Out:
# ✅ Block 1 & 2: Cloud Brain swapped to the OpenRouter Free Load-Balancer!

# %%
import subprocess

def search_chub_docs(query: str) -> str:
    """
    Search Context Hub (chub) for the latest 2026 API documentation and SDK standards.
    Use this tool whenever you need to verify model names (like gpt-5.2) or correct SDK syntax.
    """
    try:
        # Executes the terminal command 'chub search' and captures the output
        result = subprocess.run(['chub', 'search', query], capture_output=True, text=True)
        if result.returncode == 0:
            return result.stdout
        else:
            return f"Error searching chub: {result.stderr}"
    except Exception as e:
        return f"Failed to execute chub search: {str(e)}"

print("✅ Step 2: Documentation Search Tool Defined")
# Out:
# ✅ Step 2: Documentation Search Tool Defined

# %%
# 3a. The Cloud Researcher (Now Forced to Reflect)
cloud_researcher = AssistantAgent(
    name="Cloud_Researcher",
    model_client=cloud_client,
    tools=[search_chub_docs],
    reflect_on_tool_use=True, # 🛑 THE FIX: Forces the agent to read the tool output and speak!
    system_message=(
        "You are a Senior AI Engineer. Your goal is to provide deep research and code. "
        "CRITICAL: If you are generating code or referencing model specs, you MUST use the "
        "'search_chub_docs' tool first to ensure you are using the latest 2026 standards. "
        "RULE: After executing a tool, you MUST output a final, comprehensive text response "
        "synthesizing the tool's output and answering the user's original prompt."
    )
)

print("✅ Step 3 Updated: Cloud Researcher forced to reflect on tool use.")

# 3b. The Local Formatter (Stays the same)
local_formatter = AssistantAgent(
    name="Local_Formatter",
    model_client=local_client,
    system_message="You are a strict data formatter. Condense the research into 3 concise bullet points."
)

print("✅ Step 3: Cloud Researcher Equipped with Documentation Tool")
# Out:
# ✅ Step 3 Updated: Cloud Researcher forced to reflect on tool use.
# ✅ Step 3: Cloud Researcher Equipped with Documentation Tool

# %%
from autogen_agentchat.agents import UserProxyAgent
from autogen_agentchat.teams import RoundRobinGroupChat

# 3c. The Human Boss (You)
user_proxy = UserProxyAgent(
    name="Human_Admin",
    description="A human supervisor who reviews research and provides final approval."
)

# 4. Create the Supervised Team (Replacing 'hybrid_team')
supervised_team = RoundRobinGroupChat(
    participants=[cloud_researcher, local_formatter, user_proxy], 
    max_turns=6 # Turn 1: Cloud researches, Turn 2: Local formats, Turn 3: YOU review
)

print("✅ Step 4 Updated: Supervised Team and Human Proxy defined!")

# 5. The Integrated Execution (Agriculture + Technical Precision)
async def run_integrated_suite():
    print("--- 🌾 Starting Integrated Research & Verification ---")
    
    # This task combines your MAIN purpose with your NEW technical power
    task = (
        "Part 1: Analyze the primary benefits of precision agriculture using drone technology. "
        "Part 2: Use your 'search_chub_docs' tool to find the 2026 standard for 'openai/vision' "
        "and explain how it could be used to analyze the drone imagery described in Part 1."
    )
    
    try:
        # This will run the Researcher -> Formatter -> You (Human_Admin)
        await Console(
            supervised_team.run_stream(task=task)
        )
    except Exception as e:
        print(f"⚠️ System Error: {e}")

# TRIGGER THE FULL SUITE
await run_integrated_suite()
# Out:
# ✅ Step 4 Updated: Supervised Team and Human Proxy defined!
# --- 🌾 Starting Integrated Research & Verification ---
# ---------- TextMessage (user) ----------
# Part 1: Analyze the primary benefits of precision agriculture using drone technology. Part 2: Use your 'search_chub_docs' tool to find the 2026 standard for 'openai/vision' and explain how it could be used to analyze the drone imagery described in Part 1.
# ---------- ToolCallRequestEvent (Cloud_Researcher) ----------
# [FunctionCall(id='chatcmpl-tool-854fafe4153cabc2', arguments='{"query": "2026 standard for openai/vision"}', name='search_chub_docs')]
# ---------- ToolCallExecutionEvent (Cloud_Researcher) ----------
# [FunctionExecutionResult(content='\x1b20 results for "2026 standard for openai/vision":\x1b\n\x1b\x1b\n  \x1beslint/eslint-config-standard\x1b  \x1b[doc]\x1b  \x1bjs\x1b  \x1b[maintainer]\x1b\n       \x1bStandardJS shareable ESLint config for JavaScript project...\x1b\n  \x1bapache-airflow/providers-salesforce\x1b  \x1b[doc]\x1b  \x1bpy\x1b  \x1b[maintainer]\x1b\n       \x1bApache Airflow provider for configuring Salesforce connec...\x1b\n  \x1baws/cloudformation\x1b  \x1b[doc]\x1b  \x1bjs\x1b  \x1b[maintainer]\x1b\n       \x1bAWS SDK for JavaScript v3 CloudFormation client for creat...\x1b\n  \x1baws/forecast\x1b  \x1b[doc]\x1b  \x1bjs\x1b  \x1b[maintainer]\x1b\n       \x1bAWS SDK for JavaScript v3 client for Amazon Forecast data...\x1b\n  \x1baws/mypy-boto3-cloudformation\x1b  \x1b[doc]\x1b  \x1bpy\x1b  \x1b[maintainer]\x1b\n       \x1bmypy-boto3-cloudformation typed stubs for boto3 CloudForm...\x1b\n  \x1baws/mypy-boto3-forecast\x1b  \x1b[doc]\x1b  \x1bpy\x1b  \x1b[maintainer]\x1b\n       \x1bmypy-boto3-forecast type stubs for boto3 Amazon Forecast ...\x1b\n  \x1bazure/ai-form-recognizer\x1b  \x1b[doc]\x1b  \x1bjs\x1b  \x1b[maintainer]\x1b\n       \x1bAzure Form Recognizer JavaScript SDK guide for authentica...\x1b\n  \x1bazure/ai-formrecognizer\x1b  \x1b[doc]\x1b  \x1bpy\x1b  \x1b[maintainer]\x1b\n       \x1bazure-ai-formrecognizer package guide for Python covering...\x1b\n  \x1bbabel/plugin-transform-for-of\x1b  \x1b[doc]\x1b  \x1bjs\x1b  \x1b[maintainer]\x1b\n       \x1bBabel plugin for rewriting JavaScript for...of loops duri...\x1b\n  \x1bdjango/crispy-forms\x1b  \x1b[doc]\x1b  \x1bpy\x1b  \x1b[maintainer]\x1b\n       \x1bdjango-crispy-forms 2.6 for Python - practical guide to t...\x1b\n  \x1bgoogle/aiplatform\x1b  \x1b[doc]\x1b  \x1bjs, py\x1b  \x1b[maintainer]\x1b\n       \x1bGoogle Cloud Vertex AI Node.js client for managing Vertex...\x1b\n  \x1bgoogle/dataform\x1b  \x1b[doc]\x1b  \x1bpy\x1b  \x1b[maintainer]\x1b\n       \x1bGoogle Cloud Dataform Python client for repositories, wor...\x1b\n  \x1bhuggingface/transformers\x1b  \x1b[doc]\x1b  \x1bjs\x1b  \x1b[maintainer]\x1b\n       \x1bTransformers.js coding guidelines for running ML models i...\x1b\n  \x1bvercel/platform\x1b  \x1b[doc]\x1b  \x1bjs\x1b  \x1b[maintainer]\x1b\n       \x1bVercel SDK for deploying, managing, and interacting with ...\x1b\n  \x1bnbformat/package\x1b  \x1b[doc]\x1b  \x1bpy\x1b  \x1b[maintainer]\x1b\n       \x1bnbformat package guide for reading, validating, convertin...\x1b\n  \x1bplatformdirs/package\x1b  \x1b[doc]\x1b  \x1bpy\x1b  \x1b[maintainer]\x1b\n       \x1bplatformdirs package guide for Python: platform-specific ...\x1b\n  \x1bsalesforce/crm\x1b  \x1b[doc]\x1b  \x1bjs, py\x1b  \x1b[maintainer]\x1b\n       \x1bSalesforce JavaScript SDK (JSforce) coding guidelines for...\x1b\n  \x1bsentence-transformers/package\x1b  \x1b[doc]\x1b  \x1bpy\x1b  \x1b[maintainer]\x1b\n       \x1bsentence-transformers package guide for Python embeddings...\x1b\n  \x1btransformers/package\x1b  \x1b[doc]\x1b  \x1bpy\x1b  \x1b[maintainer]\x1b\n       \x1bHugging Face Transformers Python package for loading, run...\x1b\n  \x1bbabel/plugin-transform-arrow-functions\x1b  \x1b[doc]\x1b  \x1bjs\x1b  \x1b[maintainer]\x1b\n       \x1bBabel plugin for rewriting ES2015 arrow functions into fu...\x1b\n', name='search_chub_docs', call_id='chatcmpl-tool-854fafe4153cabc2', is_error=False)]
# ---------- TextMessage (Cloud_Researcher) ----------
# The primary benefits of precision agriculture using drone technology include increased crop yields, reduced water and fertilizer consumption, and improved crop monitoring. Drones equipped with cameras and sensors can capture high-resolution images of crops, allowing farmers to detect issues such as pests, diseases, and nutrient deficiencies early on. This enables them to take targeted actions to address these issues, reducing the need for blanket pesticide or fertilizer applications.
#
# According to the 'search_chub_docs' tool, the 2026 standard for 'openai/vision' is not explicitly stated in the search results. However, the search results do provide information on various AI and machine learning-related topics, including Google Cloud Vertex AI, Hugging Face Transformers, and Salesforce JavaScript SDK.
#
# The 'openai/vision' model could be used to analyze drone imagery in precision agriculture by leveraging its capabilities in computer vision and image analysis. The model could be trained on a dataset of images captured by drones, allowing it to learn patterns and features associated with different crop health conditions. This would enable the model to make predictions on the health of crops based on new images captured by drones, providing farmers with valuable insights to inform their decision-making.
#
# For example, the 'openai/vision' model could be used to detect early signs of disease or pest infestations, allowing farmers to take proactive measures to prevent the spread of disease or pests. The model could also be used to analyze images of crops to estimate yields, enabling farmers to make more informed decisions about harvesting and pricing.
#
# Overall, the integration of drone technology and AI models like 'openai/vision' has the potential to revolutionize precision agriculture, enabling farmers to make more informed decisions, reduce waste, and improve crop yields.
# ---------- TextMessage (Local_Formatter) ----------
# **Part 1: Benefits of Precision Agriculture using Drone Technology**
#
# * Increased crop yields through targeted actions to address pests, diseases, and nutrient deficiencies
# * Reduced water and fertilizer consumption through optimized application rates
# * Improved crop monitoring through high-resolution drone imagery
#
# **Part 2: Analysis of Drone Imagery using AI Models**
#
# The "openai/vision" model can be leveraged for image analysis in precision agriculture by:
# * Learning patterns and features from a dataset of images captured by drones to detect early signs of disease or pest infestations
# * Analyzing images of crops to estimate yields, enabling data-driven decisions on harvesting and pricing
# ---------- TextMessage (Human_Admin) ----------
# Approved.Terminate.
# ---------- TextMessage (Cloud_Researcher) ----------
# Terminated.
# ---------- TextMessage (Local_Formatter) ----------
# Session terminated.
# ---------- TextMessage (Human_Admin) ----------
# Approved.Terminate
